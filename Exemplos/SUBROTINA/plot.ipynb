# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load data
data = pd.read_csv(r'C:\Users\joaov\Documents\computational-physics\Cap-2\2-1\tempo.dat',header=None)

# %%
plt.plot(data[0],data[1])
